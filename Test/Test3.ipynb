# %%
from valueDataBase import DataBase
import matplotlib.pyplot as plt
import numpy as np

# %%
base=DataBase()
base.creat_sigma()
f=base.f_sigma

# %%
f

# %%
fig=plt.figure(dpi=100)
P=np.linspace(-1,4,200)
sigma=f(P)
plt.plot(P,sigma)
plt.show()

# %%
from calculator import Calculator
from test1 import Test
from const import Const

# %%
cal=Calculator()
cal.me.change_const(Const(0.3))
cal.read_excel('Data2.xlsx')
order=20
m=cal.M_p[order]
L_s=cal.L_init[order]
ST=cal.ST[order]

# %%
te=Test()
te.con.set_M_p(m)
te.cal_ML_simple_B(2e-7,L_s,True,0.0,-1)
# Out:
# (4.999992033121001, -1.4815949406496611, 43128934.69504027)

# %%
te=Test()
te.con.set_M_p(m)
te.cal_ML_simple_B(ST,L_s,True,0.0,-1)
print(te.P[-1])
# Out:
# Error
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-51-899b69a301cf> in <module>
#       1 te=Test()
#       2 te.con.set_M_p(m)
# ----> 3 te.cal_ML_simple_B(ST,L_s,True,0.0,-1)
#       4 print(te.P[-1])
#
# d:\University\Project\Test\test1.py in cal_ML_simple_B(cls, ST, L_s, B, G, dG)
#      72             initial=(1.,1.,cls.con.M_p,0.0,0.0,L_s)
#      73         others=(g,alpha,beta,cls.con.Lambda,cls.con.R_B)
# ---> 74         result=odeint(cls.ode_fun_B,initial,r,args=(c_P,c_T,c_M,others,ST))
#      75         P,T,M,G,dg,L=result[:,0],result[:,1],result[:,2],result[:,3],result[:,4],result[:,5]
#      76         cls.P,cls.T,cls.M,cls.L=P,T,M,L
#
# ...

# %%
plt.figure(dpi=100)
plt.loglog(cal.me.r,abs(cal.me.g)/cal.me.r/cal.me.con.R_B)
plt.show()

# %%
plt.figure(dpi=100)
plt.loglog(cal.me.P,cal.me.T)
plt.loglog(te.P,te.T)
plt.show()

# %%
# Out:
# 0.8302 0.875

# %%
te=Test()
te.con.set_M_p(m)

# %%
te.cal_ML_simple_B(ST,L_s,True,0.0,-1)
# Out:
# (5.000000281638749, 1.1134462606425706e-05, 7341966.796157204)

# %%
cal.me.con.set_M_p(m)
cal.me.cal_ML_simple(ST,L_s)
# Out:
# (5.00000007950821, 1.0007753114184975e-05)

# %%
fig=plt.figure(dpi=100)
plt.loglog(te.r,te.L)
plt.show()
